# %% [markdown]
# # Assignment 2.1: Feed-Forward Neural Network
# Student Name 1: ...
#
# Student Name 2: ...
#
# Student Name 3: ...

# %% [markdown]
# ## German Traffic Sign Benchmark

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate "https://docs.google.com/uc?export=download&id=1De6T4b6mtFQALtuyT05zxGkS1YHKXG01" -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1De6T4b6mtFQALtuyT05zxGkS1YHKXG01" -O FullIJCNN2013.zip && rm -rf /tmp/cookies.txt
# !unzip FullIJCNN2013.zip
# Out:
# "wget" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.
# id: unknown option -- O
# Try 'id --help' for more information.
# unzip:  cannot find or open FullIJCNN2013.zip, FullIJCNN2013.zip.zip or FullIJCNN2013.zip.ZIP.

# %%
import numpy as np
import cv2

IMG_HEIGHT = 600
SIGN_SIZE = (224, 224)

# Function for reading the images
def readImages(rootpath, images_range, signs_range):
    '''Reads traffic sign data for German Traffic Sign Recognition Benchmark.
    Arguments: path to the traffic sign data, for example 'FullIJCNN2013'
    Returns:   list of images, list of corresponding labels'''
    images = {} # original image
    scales = {} # original scale
    for num in images_range:
        filename = rootpath + '/' + "{:05d}".format(num) + '.ppm'
        img = cv2.imread(filename, cv2.IMREAD_COLOR)
        scale = IMG_HEIGHT / float(img.shape[0])
        img_resized = cv2.resize(img, (int(img.shape[1]*scale),int(img.shape[0]*scale)))
        images.setdefault(filename,[]).append(img_resized)
        scales.setdefault(filename,[]).append(scale)

    files = [] # filenames
    signs = [] # traffic sign image
    bboxes = [] # corresponding box detection
    labels = [] # traffic sign type
    data = np.genfromtxt(rootpath + '/' + 'gt.txt', delimiter=';', dtype=str, usecols=range(0, 6))
    for elem in signs_range:
        filename = rootpath + '/' + data[elem][0]
        img = images.get(filename)[0]
        scale = scales.get(filename)[0]
        bbox = np.array([int(data[elem][1]), int(data[elem][2]), int(data[elem][3]), int(data[elem][4])]) * scale
        sign = img[int(bbox[1]):int(bbox[3]), int(bbox[0]):int(bbox[2])]
        sign_resized = cv2.resize(sign, SIGN_SIZE)
        files.append(filename)
        signs.append(sign_resized)
        bboxes.append(bbox)
        labels.append(data[elem][5])
    return images, files, signs, bboxes, labels

# %%
# The German Traffic Sign Recognition Benchmark
train_images, train_files, train_signs, train_bboxes, train_labels = readImages('data/FullIJCNN2013', range(0,600), range(0,852))
test_images, test_files, test_signs, test_bboxes, test_labels = readImages('data/FullIJCNN2013', range(600,900), range(852,1213))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

# Show examples from each class
class_names = np.unique(train_labels)
num_classes = len(class_names)
fig = plt.figure(figsize=(8,8))
for i in range(num_classes):
    ax = fig.add_subplot(6, 9, 1 + i, xticks=[], yticks=[])
    ax.set_title(class_names[i])
    indices = np.where(np.isin(train_labels, class_names[i]))[0]
    plt.imshow(cv2.cvtColor(train_signs[int(np.random.choice(indices, 1))], cv2.COLOR_BGR2RGB))
plt.show()

# %%
#!pip install keras
from sklearn.utils import shuffle
train_files, train_signs, train_bboxes, train_labels = shuffle(train_files, train_signs, train_bboxes, train_labels)
# plt.imshow(cv2.cvtColor(train_images.get(train_files[0])[0], cv2.COLOR_BGR2RGB))
# plt.show()
# plt.imshow(cv2.cvtColor(train_signs[0], cv2.COLOR_BGR2RGB))
# plt.show()
# print(train_bboxes[0])
# print(train_labels[0])

# Data pre-processing
tr_signs = np.array(train_signs)[0:600]
tr_labels = np.array(train_labels)[0:600]
va_signs = np.array(train_signs)[600:852]
va_labels = np.array(train_labels)[600:852]
te_signs = np.array(test_signs)
te_labels = np.array(test_labels)

# Normalize the images to be values in range [0, 1]
tr_signs = tr_signs.astype('float32')
va_signs = va_signs.astype('float32')
te_signs = te_signs.astype('float32')
tr_signs /= 255.0
va_signs /= 255.0
te_signs /= 255.0

from keras.utils import np_utils
# Converts a class vector (integers) to binary class matrix
tr_labels = np_utils.to_categorical(tr_labels, num_classes)
va_labels = np_utils.to_categorical(va_labels, num_classes)
te_labels = np_utils.to_categorical(te_labels, num_classes)
# Out:
# Requirement already satisfied: keras in c:\users\mariano\anaconda3\lib\site-packages (2.3.1)
# Requirement already satisfied: scipy>=0.14 in c:\users\mariano\anaconda3\lib\site-packages (from keras) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in c:\users\mariano\anaconda3\lib\site-packages (from keras) (1.1.0)
# Requirement already satisfied: keras-applications>=1.0.6 in c:\users\mariano\anaconda3\lib\site-packages (from keras) (1.0.8)
# Requirement already satisfied: six>=1.9.0 in c:\users\mariano\anaconda3\lib\site-packages (from keras) (1.12.0)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\mariano\anaconda3\lib\site-packages (from keras) (1.18.1)
# Requirement already satisfied: pyyaml in c:\users\mariano\anaconda3\lib\site-packages (from keras) (3.13)
# Requirement already satisfied: h5py in c:\users\mariano\anaconda3\lib\site-packages (from keras) (2.8.0)
# Using TensorFlow backend.
# C:\Users\Mariano\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Mariano\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Mariano\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Mariano\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Mariano\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Mariano\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# Tensorboard
from time import time
from keras.callbacks import TensorBoard
tensorboard = TensorBoard(log_dir='logs/{}'.format(time()))

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras import optimizers

mlp = Sequential()
mlp.add(Flatten(input_shape=(SIGN_SIZE[0], SIGN_SIZE[1], 3)))
mlp.add(Activation('relu'))
mlp.add(Dropout(0.2))
mlp.add(Dense(num_classes))
mlp.add(Activation('softmax'))

opt = optimizers.SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
mlp.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
mlp.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Mariano\Anaconda3\lib\site-packages\tensorflow\python\ops\control_flow_ops.py:423: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 150528)            0
# _________________________________________________________________
# activation_1 (Activation)    (None, 150528)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 150528)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 43)                6472747
# _________________________________________________________________
# activation_2 (Activation)    (None, 43)                0
# =================================================================
# Total params: 6,472,747
# Trainable params: 6,472,747
# Non-trainable params: 0
# _________________________________________________________________

# %%
data = mlp.fit(tr_signs, tr_labels, batch_size=16, epochs=100, verbose=2, validation_data=(va_signs, va_labels), callbacks=[tensorboard])

start = time()
loss, acc = mlp.evaluate(te_signs, te_labels, verbose=0)
end = time()
print('ffNN took ' + str(end - start) + ' seconds')
print('Test loss: ' + str(loss) + ' - Accuracy: ' + str(acc))
# Out:
# WARNING:tensorflow:From C:\Users\Mariano\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 600 samples, validate on 252 samples
# Epoch 1/100
#  - 9s - loss: 9.9471 - accuracy: 0.0883 - val_loss: 10.3536 - val_accuracy: 0.2381
# Epoch 2/100
#  - 11s - loss: 8.6487 - accuracy: 0.2433 - val_loss: 8.4241 - val_accuracy: 0.2341
# Epoch 3/100
#  - 13s - loss: 7.4985 - accuracy: 0.3233 - val_loss: 7.1938 - val_accuracy: 0.3770
# Epoch 4/100
#  - 12s - loss: 6.3529 - accuracy: 0.4117 - val_loss: 6.6903 - val_accuracy: 0.3571
# Epoch 5/100
#  - 8s - loss: 5.8738 - accuracy: 0.4700 - val_loss: 5.9957 - val_accuracy: 0.4444
# Epoch 6/100
#  - 9s - loss: 5.3560 - accuracy: 0.5817 - val_loss: 5.4794 - val_accuracy: 0.5317
# Epoch 7/100
#  - 9s - loss: 5.5477 - accuracy: 0.5583 - val_loss: 5.8797 - val_accuracy: 0.4444
# Epoch 8/100
#  - 9s - loss: 5.3722 - accuracy: 0.5483 - val_loss: 5.8352 - val_accuracy: 0.4960
# Epoch 9/100
#  - 12s - loss: 5.2273 - accuracy: 0.5700 - val_loss: 5.7402 - val_accuracy: 0.4841
# Epoch 10/100
#  - 8s - loss: 4.9674 - accuracy: 0.5983 - val_loss: 5.3972 - val_accuracy: 0.5317
# Epoch 11/100
#  - 7s - loss: 4.7567 - accuracy: 0.6550 - val_loss: 5.3038 - val_accuracy: 0.5476
# Epoch 12/100
#  - 7s - loss: 4.7459 - accuracy: 0.6583 - val_loss: 5.1112 - val_accuracy: 0.5516
# Epoch 13/100
#  - 9s - loss: 4.7691 - accuracy: 0.6533 - val_loss: 5.1730 - val_accuracy: 0.5556
# Epoch 14/100
#  - 6s - loss: 4.8969 - accuracy: 0.6600 - val_loss: 5.1481 - val_accuracy: 0.5794
# Epoch 15/100
#  - 7s - loss: 4.6867 - accuracy: 0.6550 - val_loss: 5.0459 - val_accuracy: 0.5754
# Epoch 16/100
#  - 7s - loss: 4.5541 - accuracy: 0.6817 - val_loss: 4.9320 - val_accuracy: 0.6190
# Epoch 17/100
#  - 8s - loss: 4.5120 - accuracy: 0.7017 - val_loss: 4.9093 - val_accuracy: 0.6032
# Epoch 18/100
#  - 7s - loss: 4.5647 - accuracy: 0.6933 - val_loss: 4.9884 - val_accuracy: 0.5833
# Epoch 19/100
#  - 9s - loss: 4.5254 - accuracy: 0.6950 - val_loss: 5.0029 - val_accuracy: 0.5992
# Epoch 20/100
#  - 9s - loss: 4.4882 - accuracy: 0.7067 - val_loss: 4.8972 - val_accuracy: 0.5913
# Epoch 21/100
#  - 8s - loss: 4.5472 - accuracy: 0.6917 - val_loss: 4.9052 - val_accuracy: 0.6071
# Epoch 22/100
#  - 6s - loss: 4.6239 - accuracy: 0.6950 - val_loss: 4.9059 - val_accuracy: 0.6111
# Epoch 23/100
#  - 5s - loss: 4.5411 - accuracy: 0.6883 - val_loss: 5.0061 - val_accuracy: 0.5873
# Epoch 24/100
#  - 5s - loss: 4.4769 - accuracy: 0.7167 - val_loss: 4.8172 - val_accuracy: 0.6151
# Epoch 25/100
#  - 5s - loss: 4.4541 - accuracy: 0.7183 - val_loss: 4.7925 - val_accuracy: 0.6190
# Epoch 26/100
#  - 5s - loss: 4.4496 - accuracy: 0.7217 - val_loss: 5.0261 - val_accuracy: 0.5873
# Epoch 27/100
#  - 5s - loss: 4.4512 - accuracy: 0.7217 - val_loss: 4.7848 - val_accuracy: 0.6270
# Epoch 28/100
#  - 5s - loss: 4.4448 - accuracy: 0.7217 - val_loss: 4.8739 - val_accuracy: 0.6230
# Epoch 29/100
#  - 5s - loss: 4.4460 - accuracy: 0.7267 - val_loss: 4.9154 - val_accuracy: 0.5952
# Epoch 30/100
#  - 6s - loss: 4.4465 - accuracy: 0.7233 - val_loss: 4.8029 - val_accuracy: 0.6151
# Epoch 31/100
#  - 6s - loss: 4.4396 - accuracy: 0.7250 - val_loss: 4.8493 - val_accuracy: 0.6190
# Epoch 32/100
#  - 5s - loss: 4.4372 - accuracy: 0.7267 - val_loss: 4.8563 - val_accuracy: 0.6111
# Epoch 33/100
#  - 5s - loss: 4.4389 - accuracy: 0.7200 - val_loss: 4.7932 - val_accuracy: 0.6190
# Epoch 34/100
#  - 5s - loss: 4.4340 - accuracy: 0.7267 - val_loss: 4.8651 - val_accuracy: 0.6151
# Epoch 35/100
#  - 5s - loss: 4.4357 - accuracy: 0.7217 - val_loss: 4.8679 - val_accuracy: 0.6111
# Epoch 36/100
#  - 6s - loss: 4.4339 - accuracy: 0.7267 - val_loss: 4.8258 - val_accuracy: 0.6151
# Epoch 37/100
#  - 5s - loss: 4.4297 - accuracy: 0.7283 - val_loss: 4.8602 - val_accuracy: 0.6111
# Epoch 38/100
#  - 5s - loss: 4.4294 - accuracy: 0.7283 - val_loss: 4.8222 - val_accuracy: 0.6190
# Epoch 39/100
#  - 5s - loss: 4.4296 - accuracy: 0.7233 - val_loss: 4.8571 - val_accuracy: 0.6111
# Epoch 40/100
#  - 6s - loss: 4.4273 - accuracy: 0.7250 - val_loss: 4.8569 - val_accuracy: 0.6230
# Epoch 41/100
#  - 5s - loss: 4.4265 - accuracy: 0.7283 - val_loss: 4.8266 - val_accuracy: 0.6270
# Epoch 42/100
#  - 5s - loss: 4.4265 - accuracy: 0.7250 - val_loss: 4.8172 - val_accuracy: 0.6230
# Epoch 43/100
#  - 5s - loss: 4.4280 - accuracy: 0.7250 - val_loss: 4.8547 - val_accuracy: 0.6151
# Epoch 44/100
#  - 5s - loss: 4.4263 - accuracy: 0.7267 - val_loss: 4.8377 - val_accuracy: 0.6032
# Epoch 45/100
#  - 6s - loss: 4.4218 - accuracy: 0.7267 - val_loss: 4.8017 - val_accuracy: 0.6349
# Epoch 46/100
#  - 5s - loss: 4.4233 - accuracy: 0.7267 - val_loss: 4.8273 - val_accuracy: 0.6270
# Epoch 47/100
#  - 6s - loss: 4.4216 - accuracy: 0.7283 - val_loss: 4.8285 - val_accuracy: 0.6151
# Epoch 48/100
#  - 6s - loss: 4.4225 - accuracy: 0.7267 - val_loss: 4.8464 - val_accuracy: 0.6190
# Epoch 49/100
#  - 10s - loss: 4.4195 - accuracy: 0.7283 - val_loss: 4.8525 - val_accuracy: 0.6190
# Epoch 50/100
#  - 9s - loss: 4.4213 - accuracy: 0.7267 - val_loss: 4.8084 - val_accuracy: 0.6310
# Epoch 51/100
#  - 9s - loss: 4.4192 - accuracy: 0.7283 - val_loss: 4.8114 - val_accuracy: 0.6389
# Epoch 52/100
#  - 9s - loss: 4.4180 - accuracy: 0.7283 - val_loss: 4.8225 - val_accuracy: 0.6310
# Epoch 53/100
#  - 10s - loss: 4.4190 - accuracy: 0.7283 - val_loss: 4.8134 - val_accuracy: 0.6389
# Epoch 54/100
#  - 9s - loss: 4.4234 - accuracy: 0.7267 - val_loss: 4.8215 - val_accuracy: 0.6349
# Epoch 55/100
#  - 9s - loss: 4.4155 - accuracy: 0.7283 - val_loss: 4.8197 - val_accuracy: 0.6270
# Epoch 56/100
#  - 8s - loss: 4.4189 - accuracy: 0.7267 - val_loss: 4.8223 - val_accuracy: 0.6349
# Epoch 57/100
#  - 8s - loss: 4.4158 - accuracy: 0.7283 - val_loss: 4.8279 - val_accuracy: 0.6270
# Epoch 58/100
#  - 8s - loss: 4.4159 - accuracy: 0.7283 - val_loss: 4.9250 - val_accuracy: 0.6071
# Epoch 59/100
#  - 8s - loss: 4.4162 - accuracy: 0.7283 - val_loss: 4.8424 - val_accuracy: 0.6310
# Epoch 60/100
#  - 7s - loss: 4.4127 - accuracy: 0.7283 - val_loss: 4.8285 - val_accuracy: 0.6270
# Epoch 61/100
#  - 7s - loss: 4.4131 - accuracy: 0.7283 - val_loss: 4.8554 - val_accuracy: 0.6230
# Epoch 62/100
#  - 7s - loss: 4.4134 - accuracy: 0.7283 - val_loss: 4.8353 - val_accuracy: 0.6230
# Epoch 63/100
#  - 7s - loss: 4.4165 - accuracy: 0.7267 - val_loss: 4.8337 - val_accuracy: 0.6270
# Epoch 64/100
#  - 8s - loss: 4.4100 - accuracy: 0.7283 - val_loss: 4.8161 - val_accuracy: 0.6270
# Epoch 65/100
#  - 8s - loss: 4.4113 - accuracy: 0.7283 - val_loss: 4.8099 - val_accuracy: 0.6230
# Epoch 66/100
#  - 7s - loss: 4.4109 - accuracy: 0.7283 - val_loss: 4.8117 - val_accuracy: 0.6349
# Epoch 67/100
#  - 7s - loss: 4.4109 - accuracy: 0.7283 - val_loss: 4.8176 - val_accuracy: 0.6270
# Epoch 68/100
#  - 8s - loss: 4.4100 - accuracy: 0.7283 - val_loss: 4.8199 - val_accuracy: 0.6349
# Epoch 69/100
#  - 8s - loss: 4.4092 - accuracy: 0.7283 - val_loss: 4.8430 - val_accuracy: 0.6270
# Epoch 70/100
#  - 8s - loss: 4.4097 - accuracy: 0.7283 - val_loss: 4.8228 - val_accuracy: 0.6310
# Epoch 71/100
#  - 8s - loss: 4.4085 - accuracy: 0.7283 - val_loss: 4.8281 - val_accuracy: 0.6349
# Epoch 72/100
#  - 8s - loss: 4.4077 - accuracy: 0.7283 - val_loss: 4.8221 - val_accuracy: 0.6349
# Epoch 73/100
#  - 8s - loss: 4.4071 - accuracy: 0.7283 - val_loss: 4.8449 - val_accuracy: 0.6270
# Epoch 74/100
#  - 8s - loss: 4.4069 - accuracy: 0.7283 - val_loss: 4.8220 - val_accuracy: 0.6349
# Epoch 75/100
#  - 8s - loss: 4.4066 - accuracy: 0.7283 - val_loss: 4.8035 - val_accuracy: 0.6389
# Epoch 76/100
#  - 8s - loss: 4.4071 - accuracy: 0.7283 - val_loss: 4.8055 - val_accuracy: 0.6349
# Epoch 77/100
#  - 8s - loss: 4.4063 - accuracy: 0.7283 - val_loss: 4.8206 - val_accuracy: 0.6349
# Epoch 78/100
#  - 8s - loss: 4.4065 - accuracy: 0.7283 - val_loss: 4.8134 - val_accuracy: 0.6349
# Epoch 79/100
#  - 8s - loss: 4.4064 - accuracy: 0.7283 - val_loss: 4.8207 - val_accuracy: 0.6349
# Epoch 80/100
#  - 8s - loss: 4.4054 - accuracy: 0.7283 - val_loss: 4.8202 - val_accuracy: 0.6389
# Epoch 81/100
#  - 8s - loss: 4.4053 - accuracy: 0.7283 - val_loss: 4.8190 - val_accuracy: 0.6310
# Epoch 82/100
#  - 8s - loss: 4.4041 - accuracy: 0.7283 - val_loss: 4.8412 - val_accuracy: 0.6230
# Epoch 83/100
#  - 9s - loss: 4.4043 - accuracy: 0.7283 - val_loss: 4.8448 - val_accuracy: 0.6270
# Epoch 84/100
#  - 9s - loss: 4.4041 - accuracy: 0.7283 - val_loss: 4.8329 - val_accuracy: 0.6349
# Epoch 85/100
#  - 12s - loss: 4.4034 - accuracy: 0.7283 - val_loss: 4.8399 - val_accuracy: 0.6230
# Epoch 86/100
#  - 10s - loss: 4.4037 - accuracy: 0.7283 - val_loss: 4.8353 - val_accuracy: 0.6349
# Epoch 87/100
#  - 9s - loss: 4.4039 - accuracy: 0.7283 - val_loss: 4.8283 - val_accuracy: 0.6270
# Epoch 88/100
#  - 6s - loss: 4.4024 - accuracy: 0.7283 - val_loss: 4.8148 - val_accuracy: 0.6389
# Epoch 89/100
#  - 6s - loss: 4.4026 - accuracy: 0.7283 - val_loss: 4.8271 - val_accuracy: 0.6349
# Epoch 90/100
#  - 9s - loss: 4.4033 - accuracy: 0.7283 - val_loss: 4.8296 - val_accuracy: 0.6389
# Epoch 91/100
#  - 8s - loss: 4.4028 - accuracy: 0.7283 - val_loss: 4.8233 - val_accuracy: 0.6389
# Epoch 92/100
#  - 8s - loss: 4.4030 - accuracy: 0.7283 - val_loss: 4.8300 - val_accuracy: 0.6270
# Epoch 93/100
#  - 8s - loss: 4.4033 - accuracy: 0.7283 - val_loss: 4.8359 - val_accuracy: 0.6349
# Epoch 94/100
#  - 8s - loss: 4.4016 - accuracy: 0.7283 - val_loss: 4.8544 - val_accuracy: 0.6270
# Epoch 95/100
#  - 8s - loss: 4.4005 - accuracy: 0.7283 - val_loss: 4.8174 - val_accuracy: 0.6389
# Epoch 96/100
#  - 8s - loss: 4.4011 - accuracy: 0.7283 - val_loss: 4.8630 - val_accuracy: 0.6190
# Epoch 97/100
#  - 8s - loss: 4.4014 - accuracy: 0.7283 - val_loss: 4.8245 - val_accuracy: 0.6349
# Epoch 98/100
#  - 9s - loss: 4.4007 - accuracy: 0.7283 - val_loss: 4.8151 - val_accuracy: 0.6389
# Epoch 99/100
#  - 8s - loss: 4.4001 - accuracy: 0.7283 - val_loss: 4.8216 - val_accuracy: 0.6349
# Epoch 100/100
#  - 6s - loss: 4.4007 - accuracy: 0.7283 - val_loss: 4.8427 - val_accuracy: 0.6230
# ffNN took 0.686072587966919 seconds
# Test loss: 5.352212092222599 - Accuracy: 0.6066482067108154

# %% [markdown]
# # CIFAR 100 Dataset

# %%
from keras.datasets import cifar100
(_x_train, _y_train), (_x_test, _y_test) = cifar100.load_data(label_mode='fine')

# %%
# Show examples from each class
class_names = np.unique(_y_train)
num_classes = len(class_names)

fig, axes = plt.subplots(10, 10,figsize=(15,15))
for i in range(num_classes):
    ax = axes.flatten()[i]
    indices = np.where(np.isin(_y_train, class_names[i]))[0]
    ax.imshow(_x_train[int(np.random.choice(indices, 1))])
    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)
    ax.set_title(i)
plt.show()

# %%
# Data pre-processing
x_val = _x_train[40000:]
y_val = _y_train[40000:]
x_train = _x_train[:40000]
y_train = _y_train[:40000]
x_test = _x_test
y_test = _y_test

# Normalize the images to be values in range [0, 1]
x_train = x_train.astype('float32')
x_val = x_val.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255.0
x_val /= 255.0
x_test /= 255.0

from keras.utils import np_utils
# Converts a class vector (integers) to binary class matrix
tr_labels = np_utils.to_categorical(y_train, num_classes)
va_labels = np_utils.to_categorical(y_val, num_classes)
te_labels = np_utils.to_categorical(y_test, num_classes)

CIFAR_SIZE = (32, 32)

# %%
# Tensorboard
from time import time
from keras.callbacks import TensorBoard
tensorboard = TensorBoard(log_dir='logs/{}'.format(time()))

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras import optimizers

mlp = Sequential()
mlp.add(Flatten(input_shape=(CIFAR_SIZE[0], CIFAR_SIZE[1], 3)))
mlp.add(Activation('relu'))
mlp.add(Dropout(0.2))
mlp.add(Dense(num_classes))
mlp.add(Activation('softmax'))

opt = optimizers.SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
mlp.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
mlp.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_2 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# activation_3 (Activation)    (None, 3072)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 3072)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               307300
# _________________________________________________________________
# activation_4 (Activation)    (None, 100)               0
# =================================================================
# Total params: 307,300
# Trainable params: 307,300
# Non-trainable params: 0
# _________________________________________________________________

# %%
data = mlp.fit(x_train, tr_labels, batch_size=16, epochs=100, verbose=2, validation_data=(x_val, va_labels), callbacks=[tensorboard])

start = time()
loss, acc = mlp.evaluate(x_test, te_labels, verbose=0)
end = time()
print('ffNN took ' + str(end - start) + ' seconds')
print('Test loss: ' + str(loss) + ' - Accuracy: ' + str(acc))
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/100
#  - 4s - loss: 4.2624 - accuracy: 0.0662 - val_loss: 3.9853 - val_accuracy: 0.1028
# Epoch 2/100
#  - 4s - loss: 3.9695 - accuracy: 0.1136 - val_loss: 3.9057 - val_accuracy: 0.1230
# Epoch 3/100
#  - 4s - loss: 3.8716 - accuracy: 0.1281 - val_loss: 3.8685 - val_accuracy: 0.1250
# Epoch 4/100
#  - 4s - loss: 3.8132 - accuracy: 0.1407 - val_loss: 3.8225 - val_accuracy: 0.1353
# Epoch 5/100
#  - 4s - loss: 3.7702 - accuracy: 0.1488 - val_loss: 3.7897 - val_accuracy: 0.1454
# Epoch 6/100
#  - 4s - loss: 3.7361 - accuracy: 0.1578 - val_loss: 3.7769 - val_accuracy: 0.1450
# Epoch 7/100
#  - 4s - loss: 3.7139 - accuracy: 0.1600 - val_loss: 3.7667 - val_accuracy: 0.1524
# Epoch 8/100
#  - 4s - loss: 3.6849 - accuracy: 0.1665 - val_loss: 3.7923 - val_accuracy: 0.1543
# Epoch 9/100
#  - 4s - loss: 3.6722 - accuracy: 0.1678 - val_loss: 3.7378 - val_accuracy: 0.1588
# Epoch 10/100
#  - 5s - loss: 3.6481 - accuracy: 0.1702 - val_loss: 3.7602 - val_accuracy: 0.1524
# Epoch 11/100
#  - 4s - loss: 3.6350 - accuracy: 0.1751 - val_loss: 3.7436 - val_accuracy: 0.1609
# Epoch 12/100
#  - 4s - loss: 3.6211 - accuracy: 0.1779 - val_loss: 3.7491 - val_accuracy: 0.1578
# Epoch 13/100
#  - 5s - loss: 3.6092 - accuracy: 0.1795 - val_loss: 3.7717 - val_accuracy: 0.1513
# Epoch 14/100
#  - 5s - loss: 3.5976 - accuracy: 0.1815 - val_loss: 3.7841 - val_accuracy: 0.1494
# Epoch 15/100
#  - 4s - loss: 3.5876 - accuracy: 0.1855 - val_loss: 3.7265 - val_accuracy: 0.1619
# Epoch 16/100
#  - 5s - loss: 3.5805 - accuracy: 0.1848 - val_loss: 3.7574 - val_accuracy: 0.1623
# Epoch 17/100
#  - 5s - loss: 3.5705 - accuracy: 0.1864 - val_loss: 3.7593 - val_accuracy: 0.1558
# Epoch 18/100
#  - 4s - loss: 3.5503 - accuracy: 0.1908 - val_loss: 3.7680 - val_accuracy: 0.1531
# Epoch 19/100
#  - 4s - loss: 3.5533 - accuracy: 0.1902 - val_loss: 3.7516 - val_accuracy: 0.1641
# Epoch 20/100
#  - 4s - loss: 3.5418 - accuracy: 0.1937 - val_loss: 3.7386 - val_accuracy: 0.1645
# Epoch 21/100
#  - 4s - loss: 3.5384 - accuracy: 0.1937 - val_loss: 3.7495 - val_accuracy: 0.1579
# Epoch 22/100
#  - 4s - loss: 3.5265 - accuracy: 0.1977 - val_loss: 3.7373 - val_accuracy: 0.1609
# Epoch 23/100
#  - 4s - loss: 3.5253 - accuracy: 0.1965 - val_loss: 3.7453 - val_accuracy: 0.1611
# Epoch 24/100
#  - 4s - loss: 3.5201 - accuracy: 0.1984 - val_loss: 3.7557 - val_accuracy: 0.1623
# Epoch 25/100
#  - 4s - loss: 3.5137 - accuracy: 0.1980 - val_loss: 3.7482 - val_accuracy: 0.1567
# Epoch 26/100
#  - 4s - loss: 3.5126 - accuracy: 0.1986 - val_loss: 3.7377 - val_accuracy: 0.1580
# Epoch 27/100
#  - 4s - loss: 3.4983 - accuracy: 0.2009 - val_loss: 3.7546 - val_accuracy: 0.1586
# Epoch 28/100
#  - 4s - loss: 3.4968 - accuracy: 0.2000 - val_loss: 3.7403 - val_accuracy: 0.1600
# Epoch 29/100
#  - 4s - loss: 3.4958 - accuracy: 0.1998 - val_loss: 3.7375 - val_accuracy: 0.1569
# Epoch 30/100
#  - 4s - loss: 3.4884 - accuracy: 0.2057 - val_loss: 3.7384 - val_accuracy: 0.1618
# Epoch 31/100
#  - 4s - loss: 3.4816 - accuracy: 0.2070 - val_loss: 3.7522 - val_accuracy: 0.1532
# Epoch 32/100
#  - 4s - loss: 3.4779 - accuracy: 0.2066 - val_loss: 3.7338 - val_accuracy: 0.1643
# Epoch 33/100
#  - 4s - loss: 3.4816 - accuracy: 0.2048 - val_loss: 3.7295 - val_accuracy: 0.1614
# Epoch 34/100
#  - 4s - loss: 3.4741 - accuracy: 0.2055 - val_loss: 3.7395 - val_accuracy: 0.1646
# Epoch 35/100
#  - 4s - loss: 3.4688 - accuracy: 0.2069 - val_loss: 3.7285 - val_accuracy: 0.1571
# Epoch 36/100
#  - 4s - loss: 3.4703 - accuracy: 0.2085 - val_loss: 3.7376 - val_accuracy: 0.1592
# Epoch 37/100
#  - 4s - loss: 3.4626 - accuracy: 0.2068 - val_loss: 3.7329 - val_accuracy: 0.1684
# Epoch 38/100
#  - 4s - loss: 3.4586 - accuracy: 0.2103 - val_loss: 3.7174 - val_accuracy: 0.1664
# Epoch 39/100
#  - 4s - loss: 3.4605 - accuracy: 0.2094 - val_loss: 3.7164 - val_accuracy: 0.1654
# Epoch 40/100
#  - 4s - loss: 3.4526 - accuracy: 0.2092 - val_loss: 3.7295 - val_accuracy: 0.1710
# Epoch 41/100
#  - 4s - loss: 3.4458 - accuracy: 0.2132 - val_loss: 3.7233 - val_accuracy: 0.1667
# Epoch 42/100
#  - 5s - loss: 3.4469 - accuracy: 0.2128 - val_loss: 3.7369 - val_accuracy: 0.1665
# Epoch 43/100
#  - 4s - loss: 3.4477 - accuracy: 0.2108 - val_loss: 3.7660 - val_accuracy: 0.1583
# Epoch 44/100
#  - 4s - loss: 3.4415 - accuracy: 0.2124 - val_loss: 3.7251 - val_accuracy: 0.1661
# Epoch 45/100
#  - 5s - loss: 3.4448 - accuracy: 0.2116 - val_loss: 3.7416 - val_accuracy: 0.1600
# Epoch 46/100
#  - 4s - loss: 3.4337 - accuracy: 0.2139 - val_loss: 3.7380 - val_accuracy: 0.1675
# Epoch 47/100
#  - 4s - loss: 3.4361 - accuracy: 0.2136 - val_loss: 3.7240 - val_accuracy: 0.1678
# Epoch 48/100
#  - 4s - loss: 3.4319 - accuracy: 0.2146 - val_loss: 3.7007 - val_accuracy: 0.1728
# Epoch 49/100
#  - 5s - loss: 3.4294 - accuracy: 0.2144 - val_loss: 3.7158 - val_accuracy: 0.1707
# Epoch 50/100
#  - 5s - loss: 3.4302 - accuracy: 0.2151 - val_loss: 3.7100 - val_accuracy: 0.1643
# Epoch 51/100
#  - 5s - loss: 3.4287 - accuracy: 0.2115 - val_loss: 3.7641 - val_accuracy: 0.1572
# Epoch 52/100
#  - 5s - loss: 3.4252 - accuracy: 0.2151 - val_loss: 3.7315 - val_accuracy: 0.1651
# Epoch 53/100
#  - 5s - loss: 3.4229 - accuracy: 0.2148 - val_loss: 3.7291 - val_accuracy: 0.1598
# Epoch 54/100
#  - 5s - loss: 3.4231 - accuracy: 0.2153 - val_loss: 3.7260 - val_accuracy: 0.1705
# Epoch 55/100
#  - 5s - loss: 3.4221 - accuracy: 0.2142 - val_loss: 3.7220 - val_accuracy: 0.1713
# Epoch 56/100
#  - 5s - loss: 3.4210 - accuracy: 0.2174 - val_loss: 3.7355 - val_accuracy: 0.1607
# Epoch 57/100
#  - 5s - loss: 3.4142 - accuracy: 0.2171 - val_loss: 3.7270 - val_accuracy: 0.1692
# Epoch 58/100
#  - 5s - loss: 3.4179 - accuracy: 0.2171 - val_loss: 3.7575 - val_accuracy: 0.1578
# Epoch 59/100
#  - 5s - loss: 3.4101 - accuracy: 0.2173 - val_loss: 3.7651 - val_accuracy: 0.1616
# Epoch 60/100
#  - 5s - loss: 3.4095 - accuracy: 0.2158 - val_loss: 3.7188 - val_accuracy: 0.1677
# Epoch 61/100
#  - 5s - loss: 3.4092 - accuracy: 0.2197 - val_loss: 3.7250 - val_accuracy: 0.1640
# Epoch 62/100
#  - 5s - loss: 3.4144 - accuracy: 0.2158 - val_loss: 3.7265 - val_accuracy: 0.1667
# Epoch 63/100
#  - 5s - loss: 3.4091 - accuracy: 0.2174 - val_loss: 3.7407 - val_accuracy: 0.1651
# Epoch 64/100
#  - 4s - loss: 3.4102 - accuracy: 0.2183 - val_loss: 3.7182 - val_accuracy: 0.1669
# Epoch 65/100
#  - 5s - loss: 3.4095 - accuracy: 0.2168 - val_loss: 3.7357 - val_accuracy: 0.1670
# Epoch 66/100
#  - 4s - loss: 3.4035 - accuracy: 0.2189 - val_loss: 3.7161 - val_accuracy: 0.1679
# Epoch 67/100
#  - 4s - loss: 3.4021 - accuracy: 0.2200 - val_loss: 3.7075 - val_accuracy: 0.1654
# Epoch 68/100
#  - 4s - loss: 3.4032 - accuracy: 0.2177 - val_loss: 3.7374 - val_accuracy: 0.1596
# Epoch 69/100
#  - 4s - loss: 3.4029 - accuracy: 0.2188 - val_loss: 3.7242 - val_accuracy: 0.1677
# Epoch 70/100
#  - 4s - loss: 3.3959 - accuracy: 0.2220 - val_loss: 3.7412 - val_accuracy: 0.1680
# Epoch 71/100
#  - 4s - loss: 3.3976 - accuracy: 0.2226 - val_loss: 3.7015 - val_accuracy: 0.1742
# Epoch 72/100
#  - 4s - loss: 3.3991 - accuracy: 0.2201 - val_loss: 3.7202 - val_accuracy: 0.1660
# Epoch 73/100
#  - 6s - loss: 3.3962 - accuracy: 0.2215 - val_loss: 3.7488 - val_accuracy: 0.1649
# Epoch 74/100
#  - 6s - loss: 3.3970 - accuracy: 0.2195 - val_loss: 3.7487 - val_accuracy: 0.1625
# Epoch 75/100
#  - 6s - loss: 3.3983 - accuracy: 0.2202 - val_loss: 3.7411 - val_accuracy: 0.1607
# Epoch 76/100
#  - 7s - loss: 3.3911 - accuracy: 0.2216 - val_loss: 3.7053 - val_accuracy: 0.1692
# Epoch 77/100
#  - 5s - loss: 3.3901 - accuracy: 0.2191 - val_loss: 3.7262 - val_accuracy: 0.1697
# Epoch 78/100
#  - 8s - loss: 3.3892 - accuracy: 0.2211 - val_loss: 3.7210 - val_accuracy: 0.1668
# Epoch 79/100
#  - 6s - loss: 3.3875 - accuracy: 0.2254 - val_loss: 3.7017 - val_accuracy: 0.1700
# Epoch 80/100
#  - 5s - loss: 3.3925 - accuracy: 0.2203 - val_loss: 3.7283 - val_accuracy: 0.1622
# Epoch 81/100
#  - 5s - loss: 3.3857 - accuracy: 0.2230 - val_loss: 3.7362 - val_accuracy: 0.1649
# Epoch 82/100
#  - 4s - loss: 3.3829 - accuracy: 0.2211 - val_loss: 3.7238 - val_accuracy: 0.1678
# Epoch 83/100
#  - 4s - loss: 3.3899 - accuracy: 0.2218 - val_loss: 3.7211 - val_accuracy: 0.1700
# Epoch 84/100
#  - 4s - loss: 3.3837 - accuracy: 0.2227 - val_loss: 3.7346 - val_accuracy: 0.1671
# Epoch 85/100
#  - 4s - loss: 3.3887 - accuracy: 0.2236 - val_loss: 3.7373 - val_accuracy: 0.1632
# Epoch 86/100
#  - 4s - loss: 3.3859 - accuracy: 0.2226 - val_loss: 3.7323 - val_accuracy: 0.1628
# Epoch 87/100
#  - 4s - loss: 3.3867 - accuracy: 0.2227 - val_loss: 3.7237 - val_accuracy: 0.1695
# Epoch 88/100
#  - 4s - loss: 3.3843 - accuracy: 0.2239 - val_loss: 3.6957 - val_accuracy: 0.1728
# Epoch 89/100
#  - 4s - loss: 3.3866 - accuracy: 0.2211 - val_loss: 3.7382 - val_accuracy: 0.1636
# Epoch 90/100
#  - 4s - loss: 3.3788 - accuracy: 0.2238 - val_loss: 3.7297 - val_accuracy: 0.1648
# Epoch 91/100
#  - 4s - loss: 3.3816 - accuracy: 0.2218 - val_loss: 3.7465 - val_accuracy: 0.1623
# Epoch 92/100
#  - 4s - loss: 3.3821 - accuracy: 0.2222 - val_loss: 3.7563 - val_accuracy: 0.1598
# Epoch 93/100
#  - 4s - loss: 3.3833 - accuracy: 0.2229 - val_loss: 3.7390 - val_accuracy: 0.1656
# Epoch 94/100
#  - 4s - loss: 3.3787 - accuracy: 0.2239 - val_loss: 3.7080 - val_accuracy: 0.1668
# Epoch 95/100
#  - 4s - loss: 3.3791 - accuracy: 0.2246 - val_loss: 3.7268 - val_accuracy: 0.1651
# Epoch 96/100
#  - 4s - loss: 3.3734 - accuracy: 0.2258 - val_loss: 3.7212 - val_accuracy: 0.1660
# Epoch 97/100
#  - 4s - loss: 3.3778 - accuracy: 0.2211 - val_loss: 3.7374 - val_accuracy: 0.1675
# Epoch 98/100
#  - 4s - loss: 3.3762 - accuracy: 0.2231 - val_loss: 3.7114 - val_accuracy: 0.1729
# Epoch 99/100
#  - 4s - loss: 3.3756 - accuracy: 0.2257 - val_loss: 3.7397 - val_accuracy: 0.1660
# Epoch 100/100
#  - 4s - loss: 3.3804 - accuracy: 0.2251 - val_loss: 3.7239 - val_accuracy: 0.1731
# ffNN took 0.2378537654876709 seconds
# Test loss: 3.7381041427612303 - Accuracy: 0.17270000278949738
